# %% [raw]
# ---
# title: "DS 112 Lecture Notes"
# format:
#   html:
#     theme: [minty]
#     toc: true
#     toc-depth: 1
#     number-sections: true
#     css: styles.css
#   pdf:
#     theme: [minty]
#     toc: true
#     toc-depth: 1
#     number-sections: true
#     css: styles.css
# editor: visual
# #execute:
# #  cache: true
# ---

# %%
#| include: false
import pandas as pd

# %% [markdown]
# ::: lectitle
# # Tabular Data Summaries
#
# [Slides](slides-01-tabular-data-summaries.html)
# :::
#
# {{< include 01-tabular-data-summaries.qmd >}}
#
# ::: lectitle
# # Visualization and Conditional Distributions
#
# [Slides](slides-02-conditional_distributions.html)
# :::
#
# {{< include 02-conditional_distributions.qmd >}}
#
# ::: lectitle
# # Visualizing and Summarizing Quantitative Variables
#
# [Slides](slides-03-quantitative_variables.html)
# :::
#
# {{< include 03-quantitative_variables.qmd >}}
#
# ::: lectitle
# # Multivariate Summaries
#
# [Slides](slides-04-group_by.html)
# :::
#
# {{< include 04-group_by.qmd >}}
#
# ::: lectitle
# # Distances
#
# [Slides](slides-05-distances.html)
# :::
#
# {{< include 05-distances.qmd >}}
#
# ::: lectitle
# # Dummy Variables and Column Tranformers
#
# [Slides](slides-06-preprocessing.html)
# :::
#
# {{< include 06-preprocessing.qmd >}}
#
# ::: lectitle
# # Text Data and TF-IDF
#
# [Slides](slides-07-text_data.html)
# :::
#
# {{< include 07-text_data.qmd >}}
#
# ::: lectitle
# # K Nearest Neighbors
#
# [Slides](slides-08-knn.html)
# :::
#
# {{< include 08-knn.qmd >}}
#
# ::: lectitle
# # Modeling and Machine Learning
#
# [Slides](slides-09-modeling.html)
# :::
#
# {{< include 09-modeling.qmd >}}
#
# ::: lectitle
# # Regression and Cross-Validation
#
# [Slides](slides-10-cross_val.html)
# :::
#
# {{< include 10-cross_val.qmd >}}
#
# ::: lectitle
# # Classification with KNN
#
# [Slides](slides-11-classification.html)
# :::
#
# {{< include 11-classification.qmd >}}
#
# ::: lectitle
# # Logistic Regression
#
# [Slides](slides-12-logistic.html)
# :::
#
# {{< include 12-logistic.qmd >}}
#
# ::: lectitle
# # Clustering with K-Means
#
# [Slides](slides-13-kmeans.html)
# :::
#
# {{< include 13-kmeans.qmd >}}
#
# ::: lectitle
# # Merging Data
#
# [Slides](slides-14-merge.html)
# :::
#
# {{< include 14-merge.qmd >}}
#
# ::: lectitle
# # Hierarchical Data and APIs
#
# [Slides](slides-15-hierarchical.html)
# :::
#
# {{< include 15-hierarchical.qmd >}}
#
# ::: lectitle
# # Webscraping
#
# [Slides](slides-16-webscraping.html)
# :::
#
# {{< include 16-webscraping.qmd >}}
